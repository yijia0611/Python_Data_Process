# %% [markdown]
# ![rmotr](https://user-images.githubusercontent.com/7065401/52071918-bda15380-2562-11e9-828c-7f95297e4a82.png)
# <hr style="margin-bottom: 40px;">
#
# <img src="https://user-images.githubusercontent.com/7065401/58563302-42466a80-8201-11e9-9948-b3e9f88a5662.jpg"
#     style="width:400px; float: right; margin: 0 40px 40px 40px;"></img>
#
# # Exercises
# ## Bike store sales

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
#
# ## Hands on!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
sales = pd.read_csv(
    'data/sales_data.csv',
    parse_dates=['Date'])

# %%
sales=pd.read_csv('D:\Repo\FreeCodeCamp-Pandas-Real-Life-Example-master\data\sales_data.csv'
,parse_dates=['Date'])

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group
# 0 2013-11-26   26  November  2013            19     Youth (<25)  \
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category
# 0               M     Canada  British Columbia      Accessories   Bike Racks  \
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost
# ...

# %%
sales.head()
# Out:
#         Date  Day     Month  Year  Customer_Age       Age_Group
# 0 2013-11-26   26  November  2013            19     Youth (<25)  \
# 1 2015-11-26   26  November  2015            19     Youth (<25)
# 2 2014-03-23   23     March  2014            49  Adults (35-64)
# 3 2016-03-23   23     March  2016            49  Adults (35-64)
# 4 2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category
# 0               M     Canada  British Columbia      Accessories   Bike Racks  \
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What's the mean of `Customers_Age`?

# %%
# your code goes here
sales.describe()
# Out:
#                                 Date            Day           Year
# count                         113036  113036.000000  113036.000000  \
# mean   2014-11-23 12:14:55.063519232      15.665753    2014.401739
# min              2011-01-01 00:00:00       1.000000    2011.000000
# 25%              2013-12-22 00:00:00       8.000000    2013.000000
# 50%              2014-06-27 00:00:00      16.000000    2014.000000
# 75%              2016-01-09 00:00:00      23.000000    2016.000000
# max              2016-07-31 00:00:00      31.000000    2016.000000
# std                              NaN       8.781567       1.272510
#
#         Customer_Age  Order_Quantity      Unit_Cost     Unit_Price
# count  113036.000000   113036.000000  113036.000000  113036.000000  \
# mean       35.919212       11.901660     267.296366     452.938427
# min        17.000000        1.000000       1.000000       2.000000
# 25%        28.000000        2.000000       2.000000       5.000000
# ...

# %% [markdown]
# Why don't you try with `.mean()`

# %%
sales['Customer_Age'].mean()
# Out:
# 35.91921157861212

# %% [markdown]
# Go ahead and show a <b>density (KDE)</b> and a <b>box plot</b> with the `Customer_Age` data:

# %%
# your code goes here
sales['Customer_Age'].plot(kind='kde',figsize=(14,6))
# Out:
# <Axes: ylabel='Density'>

# %%
sales['Customer_Age'].plot(kind='kde',figsize=(14,9))
# Out:
# <Axes: ylabel='Density'>

# %%
sales['Customer_Age'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What's the mean of `Order_Quantity`?

# %%
# your code goes here
sales['Order_Quantity'].describe()
# Out:
# count    113036.000000
# mean         11.901660
# std           9.561857
# min           1.000000
# 25%           2.000000
# 50%          10.000000
# 75%          20.000000
# max          32.000000
# Name: Order_Quantity, dtype: float64

# %%
sales['Order_Quantity'].mean()

# %% [markdown]
# Go ahead and show a <b>histogram</b> and a <b>box plot</b> with the `Order_Quantity` data:

# %%
# your code goes here
sales['Order_Quantity'].plot(kind='hist',bins=30,figzise=(16,6))
sales['Order_Quantity'].plot(kind='box',vert=False,figzise=(16,6))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 2
#       1 # your code goes here
# ----> 2 sales['Order_Quantity'].plot(kind='hist',bins=30,figzise=(16,6))
#       3 sales['Order_Quantity'].plot(kind='box',vert=False,figzise=(16,6))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_core.py:975, in PlotAccessor.__call__(self, *args, **kwargs)
#     972             label_name = label_kw or data.columns
#     973             data.columns = label_name
# --> 975 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\plotting\_matplotlib\__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
# ...

# %%
sales['Order_Quantity'].plot(kind='hist', bins=30, figsize=(14,6))
# Out:
# <Axes: ylabel='Frequency'>

# %%
sales['Order_Quantity'].plot(kind='box', vert=False, figsize=(14,6))
# Out:
# <Axes: >

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales per year do we have?

# %%
# your code goes here
sales['Year'].value_counts()
# Out:
# Year
# 2014    29398
# 2016    29398
# 2013    24443
# 2015    24443
# 2012     2677
# 2011     2677
# Name: count, dtype: int64

# %%
sales['Year'].value_counts()

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the previous data:

# %%
# your code goes here
sales['Year'].value_counts().plot(kind='pie',figsize=(6,6))
# Out:
# <Axes: ylabel='count'>

# %%
sales['Year'].value_counts().plot(kind='pie', figsize=(6,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales per month do we have?

# %%
# your code goes here
sales['Month'].value_counts()
# Out:
# Month
# June         11234
# December     11200
# May          11128
# April        10182
# March         9674
# January       9284
# February      9022
# October       8750
# November      8734
# August        8200
# September     8166
# July          7462
# Name: count, dtype: int64

# %%
sales['Month'].value_counts().plot(kind='bar',figsize=(10,10))
# Out:
# <Axes: xlabel='Month'>

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the previous data:

# %%
# your code goes here
sales['Month'].value_counts().plot(kind='bar',figsize=(10,10))
# Out:
# <Axes: xlabel='Month'>

# %%
sales['Month'].value_counts().plot(kind='bar', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which country has the most sales `quantity of sales`?

# %%
# your code goes here
sales.head
# Out:
# <bound method NDFrame.head of              Date  Day     Month  Year  Customer_Age       Age_Group
# 0      2013-11-26   26  November  2013            19     Youth (<25)  \
# 1      2015-11-26   26  November  2015            19     Youth (<25)
# 2      2014-03-23   23     March  2014            49  Adults (35-64)
# 3      2016-03-23   23     March  2016            49  Adults (35-64)
# 4      2014-05-15   15       May  2014            47  Adults (35-64)
# ...           ...  ...       ...   ...           ...             ...
# 113031 2016-04-12   12     April  2016            41  Adults (35-64)
# 113032 2014-04-02    2     April  2014            18     Youth (<25)
# 113033 2016-04-02    2     April  2016            18     Youth (<25)
# 113034 2014-03-04    4     March  2014            37  Adults (35-64)
# 113035 2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category
# ...

# %%
sales['Country'].value_counts()
# Out:
# Country
# United States     39206
# Australia         23936
# Canada            14178
# United Kingdom    13620
# Germany           11098
# France            10998
# Name: count, dtype: int64

# %%
sales['Country'].value_counts().head(1)

# %%
sales['Country'].value_counts()

# %% [markdown]
# Go ahead and show a <b>bar plot</b> of the sales per country:

# %%
# your code goes here
sales['Country'].value_counts().plot(kind="bar",figsize=(10,10))
# Out:
# <Axes: xlabel='Country'>

# %%
sales['Country'].value_counts().plot(kind='bar', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Create a list of every product sold

# %%
# your code goes here
sales['Product'].unique()
# Out:
# array(['Hitch Rack - 4-Bike', 'All-Purpose Bike Stand',
#        'Mountain Bottle Cage', 'Water Bottle - 30 oz.',
#        'Road Bottle Cage', 'AWC Logo Cap', 'Bike Wash - Dissolver',
#        'Fender Set - Mountain', 'Half-Finger Gloves, L',
#        'Half-Finger Gloves, M', 'Half-Finger Gloves, S',
#        'Sport-100 Helmet, Black', 'Sport-100 Helmet, Red',
#        'Sport-100 Helmet, Blue', 'Hydration Pack - 70 oz.',
#        'Short-Sleeve Classic Jersey, XL',
#        'Short-Sleeve Classic Jersey, L', 'Short-Sleeve Classic Jersey, M',
#        'Short-Sleeve Classic Jersey, S', 'Long-Sleeve Logo Jersey, M',
#        'Long-Sleeve Logo Jersey, XL', 'Long-Sleeve Logo Jersey, L',
#        'Long-Sleeve Logo Jersey, S', 'Mountain-100 Silver, 38',
#        'Mountain-100 Silver, 44', 'Mountain-100 Black, 48',
#        'Mountain-100 Silver, 48', 'Mountain-100 Black, 38',
#        'Mountain-200 Silver, 38', 'Mountain-100 Black, 44',
# ...

# %%
#sales.loc[:, 'Product'].unique()

sales['Product'].unique()
# Out:
# array(['Hitch Rack - 4-Bike', 'All-Purpose Bike Stand',
#        'Mountain Bottle Cage', 'Water Bottle - 30 oz.',
#        'Road Bottle Cage', 'AWC Logo Cap', 'Bike Wash - Dissolver',
#        'Fender Set - Mountain', 'Half-Finger Gloves, L',
#        'Half-Finger Gloves, M', 'Half-Finger Gloves, S',
#        'Sport-100 Helmet, Black', 'Sport-100 Helmet, Red',
#        'Sport-100 Helmet, Blue', 'Hydration Pack - 70 oz.',
#        'Short-Sleeve Classic Jersey, XL',
#        'Short-Sleeve Classic Jersey, L', 'Short-Sleeve Classic Jersey, M',
#        'Short-Sleeve Classic Jersey, S', 'Long-Sleeve Logo Jersey, M',
#        'Long-Sleeve Logo Jersey, XL', 'Long-Sleeve Logo Jersey, L',
#        'Long-Sleeve Logo Jersey, S', 'Mountain-100 Silver, 38',
#        'Mountain-100 Silver, 44', 'Mountain-100 Black, 48',
#        'Mountain-100 Silver, 48', 'Mountain-100 Black, 38',
#        'Mountain-200 Silver, 38', 'Mountain-100 Black, 44',
# ...

# %% [markdown]
# Create a **bar plot** showing the 10 most sold products (best sellers):

# %%
# your code goes here
sales['Product'].value_counts().head(10).plot(kind='bar',figsize=(10,10))
# Out:
# <Axes: xlabel='Product'>

# %%
sales['Product'].value_counts().head(10).plot(kind='bar', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Unit_Cost` and `Unit_Price`?
#
# Show a <b>scatter plot</b> between both columns.

# %%
# your code goes here
sales.plot(kind='scatter',x='Unit_Cost',y='Unit_Price',figsize=(10,5))
# Out:
# <Axes: xlabel='Unit_Cost', ylabel='Unit_Price'>

# %%
sales.plot(kind='scatter', x='Unit_Cost', y='Unit_Price', figsize=(6,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Order_Quantity` and `Profit`?
#
# Show a <b>scatter plot</b> between both columns.

# %%
# your code goes here
sales.plot(kind='scatter',x= 'Order_Quantity',y='Profit',figsize=(10,4))
# Out:
# <Axes: xlabel='Order_Quantity', ylabel='Profit'>

# %%
sales.plot(kind='scatter', x='Order_Quantity', y='Profit', figsize=(6,6))
# Out:
# <Axes: xlabel='Order_Quantity', ylabel='Profit'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between `Profit` per `Country`?
#
# Show a grouped <b>box plot</b> per country with the profit values.

# %%
# your code goes here

sales[['Country','Profit']].boxplot(by='Country',figsize=(10,10))
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Country]'>

# %%
sales[['Country','Profit']].boxplot(by='Country',figsize=(6,6))
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Country]'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Can you see any relationship between the `Customer_Age` per `Country`?
#
# Show a grouped <b>box plot</b> per country with the customer age values.

# %%
# your code goes here
sales[['Customer_Age','Country']].boxplot(by='Country',figsize=(10,10))
# Out:
# <Axes: title={'center': 'Customer_Age'}, xlabel='[Country]'>

# %%
sales[['Customer_Age','Country']].boxplot(by='Country',figsize=(6,6))
# Out:
# <Axes: title={'center': 'Customer_Age'}, xlabel='[Country]'>

# %%
sales[['Customer_Age', 'Country']].boxplot(by='Country', figsize=(10,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add and calculate a new `Calculated_Date` column
#
# Use `Day`, `Month`, `Year` to create a `Date` column (`YYYY-MM-DD`).

# %%
# your code goes here
sales['Calculate_Date']= sales[['Year','Month','Day']].apply(lambda x: '{}-{}-{}'.format(x[0],x[1],x[2],axis=1))sales['Calculate_Date']= sales[['Year','Month','Day']].apply(lambda x;'{}-{}-{}'.format(sales['Calculated_Date'] = sales[['Year', 'Month', 'Day']].apply(lambda x: '{}-{}-{}'.format())

# %%
sales['Calculate_Date']= sales[['Year','Month','Day']].apply(lambda x: '{}-{}-{}'.format(x[0],x[1],x[2],axis=1))

# %%
sales['Calculated_Date'] = sales[['Year', 'Month', 'Day']].apply(lambda x: '{}-{}-{}'.format(x[0], x[1], x[2]), axis=1)

sales['Calculated_Date'].head()
# Out:
# 0    2013-November-26
# 1    2015-November-26
# 2       2014-March-23
# 3       2016-March-23
# 4         2014-May-15
# Name: Calculated_Date, dtype: object

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Parse your `Calculated_Date` column into a datetime object

# %%
# your code goes here
sales['Calculated_Date']=pd.to_datetime(sales['Calculate_Date'])

sales['Calculated_Date'].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3652, in Index.get_loc(self, key)
#    3651 try:
# -> 3652     return self._engine.get_loc(casted_key)
#    3653 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Calculate_Date'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
sales['Calculated_Date'] = pd.to_datetime(sales['Calculated_Date'])

sales['Calculated_Date'].head()

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How did sales evolve through the years?
#
# Show a <b>line plot</b> using `Calculated_Date` column as the x-axis and the count of sales as the y-axis.

# %%
# your code goes here
sales['Calculated_Date'].value_counts().plot(kind='line',figsize=(16,5))
# Out:
# <Axes: xlabel='Calculated_Date'>

# %%
sales['Calculated_Date'].value_counts().plot(kind='line', figsize=(14,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Increase 50 U$S revenue to every sale

# %%
# your code goes here
sales['Revenue']+=50

# %%
#sales['Revenue'] = sales['Revenue'] + 50

sales['Revenue'] += 50

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in `Canada` or `France`?

# %%
# your code goes here, shape 0 means the number of raws in array 
sales.loc[(sales['Country']=='Canada')|(sales['Country']=='France')].shape[0]
# Out:
# 25176

# %%
# Calculate the sum of the profit under Canada and France
sales['Profit'][(sales['Country']=='Canada')|(sales['Country']=='France')].sum()
# Out:
# 6597578

# %%
sales.loc[(sales['Country'] == 'Canada') | (sales['Country'] == 'France')].shape[0]
# Out:
# 25176

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many `Bike Racks` orders were made from Canada?

# %%
# your code goes here
sales.loc[(sales['Country']=='Canada')&(sales['Sub_Category']=='Bike Racks')].shape[0]
# Out:
# 104

# %%
sales.loc[(sales['Country'] == 'Canada') & (sales['Sub_Category'] == 'Bike Racks')].shape[0]

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in each region (state) of France?

# %%
# your code goes here
sales.loc[sales['Country']=='France','State'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 50        Seine Saint Denis
# 51        Seine Saint Denis
# 52                  Moselle
# 53                  Moselle
# 60                     Nord
#                 ...
# 112979              Essonne
# 113000              Essonne
# 113001              Essonne
# 113034        Seine (Paris)
# 113035        Seine (Paris)
# Name: State, Length: 10998, dtype: object>

# %%
sales.loc[sales['Country'] == 'France','Sub_Category'].value_counts()
# Out:
# Sub_Category
# Tires and Tubes      3482
# Road Bikes           1438
# Bottles and Cages    1374
# Helmets              1330
# Mountain Bikes        916
# Jerseys               610
# Caps                  474
# Touring Bikes         416
# Fenders               204
# Gloves                202
# Hydration Packs       106
# Shorts                106
# Cleaners              104
# Vests                  84
# Socks                  64
# Bike Racks             50
# Bike Stands            38
# Name: count, dtype: int64

# %%
france_states = sales.loc[sales['Country'] == 'France', 'State'].value_counts()

france_states
# Out:
# State
# Seine (Paris)        2328
# Seine Saint Denis    1684
# Nord                 1670
# Hauts de Seine       1084
# Essonne               994
# Yveline               954
# Seine et Marne        394
# Moselle               386
# Loiret                382
# Val d'Oise            264
# Garonne (Haute)       208
# Val de Marne          158
# Charente-Maritime     148
# Somme                 134
# Loir et Cher          120
# Pas de Calais          90
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the results:

# %%
# your code goes here
sales.loc[sales['Country'] == 'France', 'State'].value_counts().plot(kind= 'bar',figsize=(10,10))
# Out:
# <Axes: xlabel='State'>

# %%
france_states.plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='State'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales were made per category?

# %%
# your code goes here
sales['Sub_Category'].value_counts()
# Out:
# Sub_Category
# Tires and Tubes      33870
# Bottles and Cages    15876
# Road Bikes           13430
# Helmets              12158
# Mountain Bikes        8854
# Jerseys               6010
# Caps                  4358
# Fenders               4032
# Touring Bikes         3698
# Gloves                2686
# Cleaners              1802
# Shorts                1794
# Hydration Packs       1334
# Socks                 1122
# Vests                  964
# Bike Racks             592
# Bike Stands            456
# Name: count, dtype: int64

# %%
sales['Product_Category'].value_counts()

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the results:

# %%
# your code goes here
sales['Sub_Category'].value_counts().plot(kind='pie',figsize=(10,12))
# Out:
# <Axes: ylabel='count'>

# %%
sales['Product_Category'].value_counts().plot(kind='pie', figsize=(6,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made per accessory sub-categories?

# %%
# your code goes here
sales.loc[sales['Product_Category']=='Accessories','Sub_Category'].value_counts()
# Out:
# Sub_Category
# Tires and Tubes      33870
# Bottles and Cages    15876
# Helmets              12158
# Fenders               4032
# Cleaners              1802
# Hydration Packs       1334
# Bike Racks             592
# Bike Stands            456
# Name: count, dtype: int64

# %%
accessories = sales.loc[sales['Product_Category'] == 'Accessories', 'Sub_Category'].value_counts()
              
accessories
# Out:
# Sub_Category
# Tires and Tubes      33870
# Bottles and Cages    15876
# Helmets              12158
# Fenders               4032
# Cleaners              1802
# Hydration Packs       1334
# Bike Racks             592
# Bike Stands            456
# Name: count, dtype: int64

# %% [markdown]
# Go ahead and show a <b>bar plot</b> with the results:

# %%
# your code goes here
sales.loc[sales['Product_Category']=='Accessories','Sub_Category'].value_counts().plot(kind='bar',figsize=(16,4))
# Out:
# <Axes: xlabel='Sub_Category'>

# %%
accessories.plot(kind='bar', figsize=(14,6))
# Out:
# <Axes: xlabel='Sub_Category'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made per bike sub-categories?

# %%
# your code goes here

# %%
bikes = sales.loc[sales['Product_Category'] == 'Bikes', 'Sub_Category'].value_counts()

bikes

# %% [markdown]
# Go ahead and show a <b>pie plot</b> with the results:

# %%
# your code goes here

# %%
bikes.plot(kind='pie', figsize=(6,6))

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Which gender has the most amount of sales?

# %%
# your code goes here, here we dont use shape[0], because it was used for calculating how many rows 
sales['Customer_Gender'].value_counts()
# Out:
# 2

# %%
sales['Customer_Gender'].value_counts()
# Out:
# Customer_Gender
# M    58312
# F    54724
# Name: count, dtype: int64

# %%
sales['Customer_Gender'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Customer_Gender'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many sales with more than 500 in `Revenue` were made by men?

# %%
# your code goes here, "=" (Assignment Operator) whilst "==" (Equality Operator)
sales.loc[(sales['Customer_Gender']=='M')&(sales['Revenue']==500)].shape[0]
# Out:
# 9

# %%
sales.loc[(sales['Customer_Gender'] == 'M') & (sales['Revenue'] == 500)].shape[0]
# Out:
# 9

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get the top-5 sales with the highest revenue

# %%
# your code goes here
sales.sort_values(['Revenue']).head(5)
# Out:
#             Date  Day     Month  Year  Customer_Age       Age_Group
# 79623 2016-03-29   29     March  2016            24     Youth (<25)  \
# 77830 2014-06-06    6      June  2014            19     Youth (<25)
# 77801 2015-11-26   26  November  2015            18     Youth (<25)
# 95964 2016-04-17   17     April  2016            54  Adults (35-64)
# 77757 2016-05-22   22       May  2016            59  Adults (35-64)
#
#       Customer_Gender        Country                State Product_Category
# 79623               M         Canada     British Columbia      Accessories  \
# 77830               M      Australia      New South Wales      Accessories
# 77801               M      Australia             Victoria      Accessories
# 95964               F        Germany  Nordrhein-Westfalen      Accessories
# 77757               F  United States           California      Accessories
#
#           Sub_Category              Product  Order_Quantity  Unit_Cost
# ...

# %%
sales.sort_values(['Revenue'], ascending=True).head(5)
# Out:
#             Date  Day     Month  Year  Customer_Age       Age_Group
# 79623 2016-03-29   29     March  2016            24     Youth (<25)  \
# 77830 2014-06-06    6      June  2014            19     Youth (<25)
# 77801 2015-11-26   26  November  2015            18     Youth (<25)
# 95964 2016-04-17   17     April  2016            54  Adults (35-64)
# 77757 2016-05-22   22       May  2016            59  Adults (35-64)
#
#       Customer_Gender        Country                State Product_Category
# 79623               M         Canada     British Columbia      Accessories  \
# 77830               M      Australia      New South Wales      Accessories
# 77801               M      Australia             Victoria      Accessories
# 95964               F        Germany  Nordrhein-Westfalen      Accessories
# 77757               F  United States           California      Accessories
#
#           Sub_Category              Product  Order_Quantity  Unit_Cost
# ...

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Get the sale with the highest revenue

# %%
# your code goes here
highr = sales['Revenue']== sales['Revenue'].max()
sales.loc[highr]
# Out:
#              Date  Day Month  Year  Customer_Age       Age_Group
# 112073 2015-07-24   24  July  2015            52  Adults (35-64)  \
#
#        Customer_Gender    Country       State Product_Category Sub_Category
# 112073               M  Australia  Queensland         Clothing        Vests  \
#
#                         Product  Order_Quantity  Unit_Cost  Unit_Price
# 112073  Touring-1000 Yellow, 50              29       1482        2384  \
#
#         Profit   Cost  Revenue Calculated_Date
# 112073   15096  42978    58174    2015-July-24

# %%
#sales.sort_values(['Revenue'], ascending=False).head(1)

cond = sales['Revenue'] == sales['Revenue'].max()

sales.loc[cond]
# Out:
#              Date  Day Month  Year  Customer_Age       Age_Group
# 112073 2015-07-24   24  July  2015            52  Adults (35-64)  \
#
#        Customer_Gender    Country       State Product_Category Sub_Category
# 112073               M  Australia  Queensland         Clothing        Vests  \
#
#                         Product  Order_Quantity  Unit_Cost  Unit_Price
# 112073  Touring-1000 Yellow, 50              29       1482        2384  \
#
#         Profit   Cost  Revenue Calculated_Date
# 112073   15096  42978    58174    2015-July-24

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What is the mean `Order_Quantity` of orders with more than 10K in revenue?

# %%
# your code goes here
more10=sales['Revenue']>10_000
sales.loc[more10,'Order_Quantity'].mean()
# Out:
# 3.6853932584269664

# %%
cond = sales['Revenue'] > 10_000

sales.loc[cond, 'Order_Quantity'].mean()
# Out:
# 3.6853932584269664

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### What is the mean `Order_Quantity` of orders with less than 10K in revenue?

# %%
# your code goes here
less10=sales['Revenue']<=10_000
sales.loc[less10,'Order_Quantity'].mean()
# Out:
# 11.914618369987064

# %%
cond = sales['Revenue'] < 10_000

sales.loc[cond, 'Order_Quantity'].mean()
# Out:
# 11.914618369987064

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made in May of 2016?

# %%
# your code goes here
ordermay=(sales['Year']==2016)& (sales['Month']=='May')
sales.loc[ordermay,'Order_Quantity'].sum()
# Out:
# 61370

# %%
cond = (sales['Year'] == 2016) & (sales['Month'] == 'May')

sales.loc[cond].shape[0]
# Out:
# 5015

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### How many orders were made between May and July of 2016?

# %%
# your code goes here
orderbe=(sales['Year']==2016)&(sales['Month'].isin (['May','June','July']))
sales.loc[orderbe,'Order_Quantity'].shape[0]
# Out:
# 12164

# %%
cond = (sales['Year'] == 2016) & (sales['Month'].isin(['May', 'June', 'July']))

sales.loc[cond].shape[0]
# Out:
# 12164

# %% [markdown]
# Show a grouped <b>box plot</b> per month with the profit values.

# %%
# your code goes here
2016sales=sales.loc[sales['Year']==2016}
2016sales.loc[(sales['Month'],sales['Profit'])].boxplot( x='Month',figsize=(10,10))
# Out:
#   Cell In[196], line 2
#     2016sales=sales.loc[sales['Year']==2016}
#        ^
# SyntaxError: invalid decimal literal

# %%
Profit_2016=sales.loc[sales['Year']==2016,['Month','Profit']]
Profit_2016.boxplot(by='Month',figsize=(14,6))
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Month]'>

# %%
profit_2016 = sales.loc[sales['Year'] == 2016, ['Profit', 'Month']]

profit_2016.boxplot(by='Month', figsize=(14,6))
# Out:
# <Axes: title={'center': 'Profit'}, xlabel='[Month]'>

# %% [markdown]
# ![green-divider](https://user-images.githubusercontent.com/7065401/52071924-c003ad80-2562-11e9-8297-1c6595f8a7ff.png)
#
# ### Add 7.2% TAX on every sale `Unit_Price` within United States

# %%
# your code goes here
tax=sales.loc[sales['Country']=='United States','Unit_Price']
tax
tax*=1.072

# %%
#sales.loc[sales['Country'] == 'United States', 'Unit_Price'] = sales.loc[sales['Country'] == 'United States', 'Unit_Price'] * 1.072

sales.loc[sales['Country'] == 'United States', 'Unit_Price'] *= 1.072

# %% [markdown]
# ![purple-divider](https://user-images.githubusercontent.com/7065401/52071927-c1cd7100-2562-11e9-908a-dde91ba14e59.png)
