# %% [markdown]
# # Python语言与经济大数据分析

# %% [markdown]
# <font face="宋体" >郭峰（Email：guofengsfi@163.com)
# 副教授、博士生导师
# 上海财经大学公共经济与管理学院 </font>

# %% [markdown]
# ## 0.1. 课程基本情况介绍

# %% [markdown]
# ### 课程背景

# %% [markdown]
# <font face="宋体" >（1）数字经济、互联网已经广泛渗透到我们生产、生活和学习的方方面面，产生大量新型的“大数据”（Big Data）；
# （2）传统的数据处理技术和工具不太适用于大数据的情形，新兴的处理技术和工具迫切需要引入学生课堂；
# （3）Python语言作为处理大数据的最成熟工具之一，已被广泛应用于学术界和实业当中。 </font>

# %% [markdown]
# ### 课程目标

# %% [markdown]
# <font face="宋体" >（1）知识目标：掌握Python语言的基本语法规则和要点；
# （2）能力目标：能够利用Python软件解决学习和工作中的一些实际问题；
# （3）素质目标：培养编程常识，锻炼互联网时代学生的自主学习的能力和解决问题的能力</font>

# %% [markdown]
# ### 课程大纲

# %% [markdown]
# <font face="微软雅黑" size=4>第1讲 数据类型与数据结构   </font>
#     <font face="宋体" >1.1. 数据类型与变量赋值
# 1.2. 运算符
# 1.3. 列表与元组
# 1.4. 字符串
# 1.5. 字典与集合   </font>
# <font face="微软雅黑" size=4>第2讲 条件语句、循环与函数  </font>
#     <font face="宋体" >2.1. Python语句规则
# 2.2. if语句
# 2.3. while循环和for循环
# 2.4. break and continue
# 2.5. 函数
# 2.6. Python常见错误与调试  </font>
# <font face="微软雅黑" size=4>第3讲 文本分析入门  </font>
#     <font face="宋体" >3.1. 外部数据的读取与存储
# 3.2. 文本分析综合演练
# 3.3. 中文分词
# 3.4. 文本向量化表示
# 3.5. 文本编码格式
# 3.6. 第三方模块安装</font>
# <font face="微软雅黑" size=4>第4讲 网络爬虫入门 </font>
#      <font face="宋体" >4.1. 爬虫基本原理与操作
# 4.2. 正则表达式1
# 4.3. 正则表达式2
# 4.4. 网络爬虫实战案例 </font>
# <font face="微软雅黑" size=4>第5讲 网络爬虫进阶 </font>
#      <font face="宋体" >5.1. Xpath语法
# 5.2. 异步加载
# 5.3. 爬虫数据存储
# 5.4. API调用
# 5.5. 代理IP设置</font>
# <font face="微软雅黑" size=4>第6讲 Numpy和Pandas数据处理 </font>
#      <font face="宋体" >6.1. Numpy基本应用
# 6.2. Pandas基本应用1
# 6.3. Pandas基本应用2
# 6.4. Pandas高级应用1
# 6.5. Pandas高级应用2
# 6.6. Pandas方法“大全” </font>
# <font face="微软雅黑" size=4>第7讲 数据可视化  </font>
#      <font face="宋体" >7.1. Pyecharts基本操作：柱状图
# 7.2. Pyecharts基本操作：折线图
# 7.3. Pyecharts其他常见图形
# 7.4. Pyecharts可视化综合演示
# 7.5. Pyecharts高级配置  </font>
# <font face="微软雅黑" size=4>第8讲 机器学习入门 </font>
#      <font face="宋体" >8.1. 机器学习基本原理
# 8.2. 线性回归、岭回归和Lasso回归
# 8.3. K近邻算法
# 8.4. 朴素贝叶斯算法
# 8.5. 机器学习实操案例 </font>

# %% [markdown]
# ### 面向对象

# %% [markdown]
# <font face="宋体" >硕博研究生和高年级本科生</font>

# %% [markdown]
# ### 先修课程

# %% [markdown]
# <font face="宋体" >第8讲机器学习入门假定大家学习过入门级的计量经济学或者统计学原理外，其他几讲内容都没有先修课程的要求</font>

# %% [markdown]
# ### 学分学时

# %% [markdown]
# <font face="宋体" >研究生1.5学分，本科生2学分；
# 如果课时不够，第5讲网络爬虫进阶和第8讲机器学习两讲，都可以作为选学内容</font>

# %% [markdown]
# <font face="宋体" >考虑到在线课程设计的技术性需求，第5讲和第8讲的视频，大家仍然需要学习一遍，才能获得平常成绩；考虑到这两讲内容不做硬性要求，因此这两讲的章节测试内容以其他章节知识点作为替代，同时这两讲的知识点也不体现在期末考试题库当中。

# %% [markdown]
# ### 参考资料

# %% [markdown]
# <font face="宋体" >阅读书目：
# 刘宇宙，《Python3.5从零开始学》，清华大学出版社，2017年。
# 罗攀、蒋仟，《从零开始学Python网络爬虫》，机械工业出版社，2017年。
# Wes McKinney，《利用Python进行数据分析》，机械工业出版社，2018年。
# 涂铭、刘祥、刘树春，《Python自然语言处理实践：核心技术与算法》，机械工业出版社，2018年。
# Muller and Guido ，《Python机器学习基础教程》，中国工信出版集团，2018年。  </font>

# %% [markdown]
# <font face="宋体" >网络参考资料：
# 可以作为速查手册，也可以进行查漏补缺。
# https://www.runoob.com/python3/python3-tutorial.html
# https://www.liaoxuefeng.com/wiki/1016959663602400
# python的官网中文文档：https://docs.python.org/zh-cn/3/</font>

# %% [markdown]
# <font face="宋体" >"干中学"是Python学习的最好途径 </font>

# %% [markdown]
# ### 授课教师简介

# %% [markdown]
# <font face="宋体" >郭峰，经济学博士，金融学博士后，现为上海财经大学公共经济与管理学院投资系副教授、博士生导师，同时兼任北京大学数字金融研究中心特约高级研究员，曾任金融专业智库上海新金融研究院专职研究员数年。研究范围广泛分布于金融学、政治经济学和文献计量学等领域，目前主要研究兴趣是探索机器学习在经济学中的应用。发表中英文学术论文40余篇，其中包括《经济研究》、《经济学季刊》、《管理世界》、《世界经济》等中文权威期刊和Journalof Economic Behavior & Organization, Resource and Energy Economics, Scientometrics和Journal of Environmental Management等英文SSCI/SCI一区期刊。另在主流媒体发表经济时评90余篇，出版专著两部，合（参）著多部。主持国家社科基金青年项目、上海市社科基金等省部级以上课题，主持或参与横向课题10余项。 </font>

# %% [markdown]
# ### 联系方式

# %% [markdown]
# <font face="宋体" >邮箱：guofengsfi@163.com
# 个人主页：http://www.guof1984.net/
# 公众号：经济数据勘探小分队（guofeng0406）
# </font>

# %%
from IPython.display import Image
path='D:/python/郭峰Python讲义/数据与结果/00课前准备工作/'
Image(filename = path+'公众号二维码.jpg', width=500, height=260)

# %%
from IPython.display import Image
path='D:/python/郭峰Python讲义/数据与结果/00课前准备工作/'
Image(filename = path+'公众号二维码.jpg', width=500, height=260)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 3
#       1 from IPython.display import Image
#       2 path='D:/python/郭峰Python讲义/数据与结果/00课前准备工作/'
# ----> 3 Image(filename = path+'公众号二维码.jpg', width=500, height=260)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\display.py:970, in Image.__init__(self, data, url, filename, format, embed, width, height, retina, unconfined, metadata, alt)
#     968 self.unconfined = unconfined
#     969 self.alt = alt
# --> 970 super(Image, self).__init__(data=data, url=url, filename=filename,
#     971         metadata=metadata)
#     973 if self.width is None and self.metadata.get('width', {}):
#     974     self.width = metadata['width']
#
# ...

# %% [markdown]
# ## 0.2. 软件安装与课前准备

# %% [markdown]
# ### Python 3 软件

# %% [markdown]
# <font face="宋体" >Python 分为Python 2和Python 3 两个不同系列，差异较大，不兼容。新学者自然学习最新的Phthon 3,本课件为Python3.6编写，目前3.9已出。需要注意的是，网络上找到的很多程序是用python 2编写的，特别是前几年共享到网络上的代码，但Python 2 已经于2020年1月1日正式弃用了。</font>

# %% [markdown]
# <font face="宋体" >网络上寻找的code，判断其为python 2，还是python 3的简单办法，看print后面是否有括号。Python 3 与Python 2 的结果打印方式不同，Python3的打印：print(x)，Python2的打印 print x</font>

# %%
#print是python的输出语句
a=1
b=1
c=a+b
print (c)

# %% [markdown]
# ### Notebook编译器

# %% [markdown]
# <font face="宋体" >很多第三方开发了基于Python的“集成开发环境”（IDE）。IDE集成了代码编写功能、分析功能、编译功能和调试功能。IDE有多个，最流行的有PyCharm等，本讲义为方便授课和演示，使用的是Jupyter Notebook。</font>

# %% [markdown]
# <font face="宋体" >Jupyter Notebook（基于网页的用于交互计算的应用程序）不仅仅适用于Python,很多其他软件也可使用 Jupyter Notebook的详细参考资料（暂无必要详学）：https://www.jianshu.com/p/91365f343585</font>

# %% [markdown]
# ### 软件安装

# %% [markdown]
# <font face="宋体" >可以直接安装程序“WinPython-64bit-3.6.2.0Qt5”，这是一个集成包，既有Python程序，也有Jupyter Notebook编辑器等。</font>

# %% [markdown]
# <font face="宋体" >这是为Window系统准备的，Mac系统需要自己网上下载相关程序</font>

# %%
from IPython.display import Image
path='D:/python/郭峰Python讲义/数据与结果/00课前准备工作/'
Image(filename = path+'软件安装示意.png', width=500, height=260)

# %% [markdown]
# <font face="宋体" >其他软件</font>

# %% [markdown]
# <font face="宋体" >“mysql-installer-community-8.0.12.0”，关系型数据库管理系统Mysql，数据量特别巨大时使用，课程第5.3节有涉及，可以暂不安装</font>

# %% [markdown]
# ### 讲义与演示数据

# %% [markdown]
# <font face="宋体" >课程的讲义，即上课所用code课件（没有PPT，只有code）</font>

# %% [markdown]
# <font face="宋体" >放入上图“notebook”文件夹。双击上述图片中的“Jupyter Notebook”，找到相应code，就可以操作。）</font>

# %% [markdown]
# <font face="宋体" >“数据与结果”文件夹当中提供了大量来自本人实际工作当中使用的数据，供课题演示及学生实际操练使用，将其中的材料放入一个如下目录的文件夹当中：“D:\python\郭峰Python讲义\数据与结果”</font>

# %% [markdown]
# <font face="宋体" >当然，上述文件夹目录并不是强制的，可以逐一修改为自己喜欢和惯用的路径，只不过本课程所有code都是以此路径为数据打开或保存的路径，逐一修改会比较麻烦</font>

# %% [markdown]
# <font face="宋体" >注：以上所提及的课程所需要的软件、讲义和演示数据在本课程的官网上均可以找到</font>

# %% [markdown]
# ### 版权声明

# %% [markdown]
# <font face="宋体" >本课程使用的程序来自网络，可以自由使用，但本课程中的其他材料，包括但不限于大纲、讲义、视频等，均由课程负责人郭峰副教授自主开发，保留知识产权，未经书面允许，谢绝任何形式的扩散。</font>
